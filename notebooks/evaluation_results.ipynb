# %% [markdown]
# # Visualizations of Model Evaluations

# %%
import os
from pathlib import Path

import pandas as pd
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_colwidth", 100)

PROJECT_ROOT = os.path.abspath("..")

# %% [markdown]
# ## ASR Model

# %%
PATH_TO_ASR_EVAL_RESULTS = Path(PROJECT_ROOT, "eval", "results", "asr_eval.parquet")

asr_eval = pd.read_parquet(PATH_TO_ASR_EVAL_RESULTS)
display(asr_eval)
# Out:
#    Model Size               Audio  \
# 0        tiny      story_1_nl.wav
# 1        tiny      story_2_nl.wav
# 2        tiny      story_3_nl.wav
# 3        tiny      story_4_nl.wav
# 4        tiny      story_5_nl.wav
# 5        tiny      story_6_nl.wav
# 6        tiny      story_7_nl.wav
# 7        tiny      story_8_nl.wav
# 8        tiny      story_9_nl.wav
# 9        tiny     story_10_nl.wav
# 10       tiny    emotion_1_nl.wav
# 11       tiny    emotion_2_nl.wav
# 12       tiny    emotion_3_nl.wav
# 13       tiny    emotion_4_nl.wav
# 14       tiny    emotion_5_nl.wav
# 15       tiny  edge_case_1_nl.wav
# 16       tiny  edge_case_2_nl.wav
# 17       tiny  edge_case_3_nl.wav
# 18       tiny  edge_case_4_nl.wav
# 19       tiny  edge_case_5_nl.wav
# 20       base      story_1_nl.wav
# 21       base      story_2_nl.wav
# 22       base      story_3_nl.wav
# 23       base      story_4_nl.wav
# 24       base      story_5_nl.wav
# 25       base      story_6_nl.wav
# ...

# %%
PATH_TO_ASR_EVAL_MEAN_RESULTS = Path(PROJECT_ROOT, "eval", "results", "asr_eval_mean.parquet")

asr_eval_mean = pd.read_parquet(PATH_TO_ASR_EVAL_MEAN_RESULTS)
display(asr_eval_mean)
# Out:
#   Model Size  Mean WER  Mean RTF
# 0       tiny  0.975516  0.157196
# 1       base  0.608952  0.133707
# 2      small  0.255366  0.223636
# 3     medium  0.184029  0.368476
# 4   large-v2  0.160986  0.551193
